# %%
import numpy as np
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# Load data
X_train = np.load("X_train.npy", mmap_mode='r')

X_train = X_train[:1000]

# Standardize the data
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X_train)

# Fit PCA on the scaled data
pca = PCA(n_components=50)
pca.fit(X_scaled)
# Out:
# PCA(n_components=50)

# %%
from nilearn.masking import unmask

mask_p = "/mnt/projects/rewardMap/STUDIES/pilotstudy/derivatives/masks/tpl-MNI152NLin2009cAsym_res-02_desc-brain_mask.nii.gz"

print(pca.components_.shape)

unmasked = unmask(pca.components_, mask_p)
# Out:
# (50, 235840)

# %%
from nilearn import plotting
import nibabel as nib
from nilearn.plotting import view_img

func_data = unmasked.get_fdata()
affine = unmasked.affine

# Create an HTML file
html_path = "all_PCs.html"
html_blocks = []

for i in range(50):
    img_3d = nib.Nifti1Image(func_data[:, :, :, i], affine)
    
    # Create an interactive viewer for this volume
    view = view_img(
        img_3d,
        bg_img=mask_p,
        cut_coords=[-8.44, 16.14, -0.5],
        title=f"PC {i+1}",
        threshold=None
    )
    
    # Convert the viewer to HTML and store it
    html_blocks.append(f"<h2>PC {i+1}</h2>" + view._repr_html_())

# Combine all HTML blocks into one file
with open(html_path, "w") as f:
    f.write("<html><body>" + "\n".join(html_blocks) + "</body></html>")
# Out:
# /mnt/scratch/projects/rewardMap/reward_signature/.venv/lib64/python3.9/site-packages/numpy/_core/fromnumeric.py:820: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   a.partition(kth, axis=axis, kind=kind, order=order)
# /mnt/scratch/projects/rewardMap/reward_signature/.venv/lib64/python3.9/site-packages/numpy/_core/fromnumeric.py:820: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   a.partition(kth, axis=axis, kind=kind, order=order)
# /mnt/scratch/projects/rewardMap/reward_signature/.venv/lib64/python3.9/site-packages/numpy/_core/fromnumeric.py:820: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   a.partition(kth, axis=axis, kind=kind, order=order)
# /mnt/scratch/projects/rewardMap/reward_signature/.venv/lib64/python3.9/site-packages/numpy/_core/fromnumeric.py:820: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
# ...

# %%
import pandas as pd
from nilearn.plotting import plot_design_matrix

path = "/mnt/projects/rewardMap/STUDIES/pilotstudy/derivatives/lss_maps/risksensitive/sub-013/des_mat_trial-050.csv"

# Load the design matrix file to inspect the first column
df = pd.read_csv(path)

# Print column names
print(df.columns)

# Print first column name and values
first_col = df.columns[0]
print("First column name:", first_col)
print(df[first_col])

# Plot using Nilearn
plot_design_matrix(df)
# Out:
# Index(['Unnamed: 0', 'reward', 'reward_050', 'csf', 'rot_x',
#        'rot_x_derivative1', 'rot_x_derivative1_power2', 'rot_x_power2',
#        'rot_y', 'rot_y_derivative1', 'rot_y_derivative1_power2',
#        'rot_y_power2', 'rot_z', 'rot_z_derivative1',
#        'rot_z_derivative1_power2', 'rot_z_power2', 'trans_x',
#        'trans_x_derivative1', 'trans_x_derivative1_power2', 'trans_x_power2',
#        'trans_y', 'trans_y_derivative1', 'trans_y_derivative1_power2',
#        'trans_y_power2', 'trans_z', 'trans_z_derivative1',
#        'trans_z_derivative1_power2', 'trans_z_power2', 'white_matter',
#        'drift_1', 'drift_2', 'drift_3', 'drift_4', 'drift_5', 'drift_6',
#        'drift_7', 'drift_8', 'drift_9', 'drift_10', 'drift_11', 'drift_12',
#        'drift_13', 'drift_14', 'drift_15', 'drift_16', 'drift_17', 'drift_18',
#        'drift_19', 'constant'],
#       dtype='object')
# First column name: Unnamed: 0
# 0         0.9
# 1         2.7
# 2         4.5
# 3         6.3
# ...
